# %% [markdown]
# <a href="https://colab.research.google.com/github/pinhas019/InfiniGen/blob/notebook-stable/InfiniGen_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Clone git repo main branch from fork
# delete local repo if exisiting, and re-clone.
![ -d "InfiniGen" ] && rm -rf "InfiniGen"
# !git clone https://github.com/pinhas019/InfiniGen.git

# %%
#@title Install python 3.9 (required to run infiniGen)
# !sudo apt-get update -y
# !sudo apt-get install python3.9 python3.9-distutils -y

# %%
#@title Install pip and create a venv
# !curl -sS https://bootstrap.pypa.io/get-pip.py | sudo python3.9
# !sudo apt install python3.9-venv
# !python3.9 -m venv /content/InfiniGen/venv-py39

# %%
#@title Activate venv and install requirements into venv
# !source /content/InfiniGen/venv-py39/bin/activate
# !pip install -r /content/InfiniGen/requirements.txt

# %%
#@title Install local packages
# !pip install -e /content/InfiniGen/speedup/infinigen/ --config-settings editable_mode=compat
# !pip install -e /content/InfiniGen/speedup/flexgen/

# Needed to run local modules since these mf's are crazy
# !pip install "numpy<2"

# %%
#@title Run a speedup test (10 min)
# %cd /content/InfiniGen/speedup/

# Always connect to GPU runtime to run this, otherwise it will crush.
# !python3.9 -m flexgen.flex_opt --model huggingface/opt-6.7b --percent 100 0 0 100 100 0 --overlap false --gpu-batch-size 2 --num-gpu-batches 1 --prompt-len 384 --gen-len 128 --warmup-input-path flexgen/pg19_firstbook.txt --test-input-path flexgen/pg19_firstbook.txt --alpha 4 --partial-weight-ratio 0.2 --max-num-kv 102
